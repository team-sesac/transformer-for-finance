# %%
# !pip install chardet
# Out:
# ...
#   Obtaining dependency information for chardet from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/199.4 kB ? eta -:--:--
#    ---------------- ----------------------- 81.9/199.4 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 199.4/199.4 kB 4.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# Try multiple encodings
possible_encodings = ['utf-8', 'euc-kr', 'cp949', 'latin1']

df1 = None  # Initialize the DataFrame variable

for encoding in possible_encodings:
    try:
        # Attempt to read the CSV file with the current encoding
        df1 = pd.read_csv("C:/Users/SBA/Desktop/final_entry_basic_info.csv", encoding=encoding)
        break  # If successful, exit the loop
    except UnicodeDecodeError:
        # If decoding error occurs, try the next encoding
        continue

# Check if DataFrame was successfully loaded
if df1 is not None:
    print("CSV file successfully loaded.")
else:
    print("Failed to load CSV file with all attempted encodings.")
# Out:
# CSV file successfully loaded.

# %%
df1 = pd.read_csv('C:/Users/SBA/Desktop/project/transformer-for-finance/src/ch3_ta/final_entry_and_xgboost/final_entry_basic_info.csv', encoding='utf-8')
df1 = df1.drop(columns=['대표자명','홈페이지','상장일','Name','종목코드','회사명','결산월'])
df1
# Out:
#         Ticker    Code                                     업종  \
# 0    와이지엔터테인먼트  122870                       오디오물 출판 및 원판 녹음업
# 1          디아이    3160  측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 2          HLB   28300                  의료용품 및 기타 의약 관련제품 제조업
# 3       현대엘리베이   17800                          일반 목적용 기계 제조업
# 4         동원금속   18500                          자동차 신품 부품 제조업
# ..         ...     ...                                    ...
# 119        파라텍   33540                          특수 목적용 기계 제조업
# 120       제룡전기   33100      전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 121       한국주강   25890                          특수 목적용 기계 제조업
# 122      신성이엔지   11930                                반도체 제조업
# 123       모베이스  101330                         통신 및 방송 장비 제조업
#
#                                                   주요제품       지역        Theme
# 0                  음악 및 기타 오디오물 출판, 신인 아티스트 육성 및 매니지먼트    서울특별시       엔터테인먼트
# ...

# %%
df2 = pd.read_csv('C:/Users/SBA/Downloads/새 폴더/all_final_entry_stock2.csv', encoding='utf-8')
df2
df2=df2.iloc[:,:10]
# Out:
#            Ticker    Code        Date     Open     High      Low    Close  \
# 0       와이지엔터테인먼트  122870  2011-11-23  25446.0  29263.0  25446.0  29263.0
# 1       와이지엔터테인먼트  122870  2011-11-24  30498.0  33641.0  30498.0  33641.0
# 2       와이지엔터테인먼트  122870  2011-11-25  34426.0  36372.0  28926.0  29787.0
# 3       와이지엔터테인먼트  122870  2011-11-28  30498.0  30984.0  28739.0  29376.0
# 4       와이지엔터테인먼트  122870  2011-11-29  29898.0  30647.0  28813.0  29376.0
# ...           ...     ...         ...      ...      ...      ...      ...
# 368027       모베이스  101330  2023-12-04   3220.0   3265.0   3195.0   3255.0
# 368028       모베이스  101330  2023-12-05   3215.0   3255.0   3200.0   3200.0
# 368029       모베이스  101330  2023-12-06   3210.0   3250.0   3205.0   3220.0
# 368030       모베이스  101330  2023-12-07   3220.0   3240.0   3210.0   3215.0
# 368031       모베이스  101330  2023-12-08   3265.0   3380.0   3210.0   3240.0
#
#            Volume    Change  pct_change
# ...

# %%
df_concat = pd.concat([df1,df2])
df_concat
# Out:
#                         Ticker           Code  \
# 0       ??´ì??í°?ì¸ë¨¼í¸         122870
# 1                ?ì??003160  ?ì??003160
# 2              ?ë??ë¦¬ë² ì´          17800
# 3                  ?ìê¸ì          18500
# 4                        ?±ì          11300
# ...                        ...            ...
# 368027                    모베이스         101330
# 368028                    모베이스         101330
# 368029                    모베이스         101330
# 368030                    모베이스         101330
# 368031                    모베이스         101330
#
#                                      ?ì¬ëª?ì¢
# ëª©ì½ë  \
# 0                                  ??´ì??í°?ì¸ë¨¼í¸
# 1       ì¸¡ì , ?í, ??´, ?ì´ ë°?ê¸°í? ?ë?ê¸°ê¸°...
# 2                                 ?ë??ë¦¬ë² ì´??017800
# 3                                             ?ìê¸ì
# 4                                                   ?±ì
# ...

# %%
merge_left = pd.merge(df1,df2, how='outer', on='Ticker')
# Out:
#                         Ticker         Code_x  \
# 0       ??´ì??í°?ì¸ë¨¼í¸         122870
# 1                ?ì??003160  ?ì??003160
# 2              ?ë??ë¦¬ë² ì´          17800
# 3                  ?ìê¸ì          18500
# 4                        ?±ì          11300
# ...                        ...            ...
# 368142                    모베이스            NaN
# 368143                    모베이스            NaN
# 368144                    모베이스            NaN
# 368145                    모베이스            NaN
# 368146                    모베이스            NaN
#
#                                      ?ì¬ëª?ì¢
# ëª©ì½ë  \
# 0                                  ??´ì??í°?ì¸ë¨¼í¸
# 1       ì¸¡ì , ?í, ??´, ?ì´ ë°?ê¸°í? ?ë?ê¸°ê¸°...
# 2                                 ?ë??ë¦¬ë² ì´??017800
# 3                                             ?ìê¸ì
# 4                                                   ?±ì
# ...
