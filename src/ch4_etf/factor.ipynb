# %% [markdown]
# https://github.com/hyunyulhenry/quant_py/tree/main/data

# %%
# !pip install pandas-datareader
# Out:
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      ---------------------------------------- 0.0/109.5 kB ? eta -:--:--
#      ---------------------------------------- 109.5/109.5 kB ? eta 0:00:00
# Collecting lxml (from pandas-datareader)
#   Downloading lxml-4.9.3-cp38-cp38-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: pandas>=0.23 in c:\venv\jupyter38\lib\site-packages (from pandas-datareader) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in c:\venv\jupyter38\lib\site-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\venv\jupyter38\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\venv\jupyter38\lib\site-packages (from pandas>=0.23->pandas-datareader) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\venv\jupyter38\lib\site-packages (from pandas>=0.23->pandas-datareader) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in c:\venv\jupyter38\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\venv\jupyter38\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\venv\jupyter38\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\venv\jupyter38\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\venv\jupyter38\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2023.7.22)
# Requirement already satisfied: six>=1.5 in c:\venv\jupyter38\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)
# Downloading lxml-4.9.3-cp38-cp38-win_amd64.whl (3.9 MB)
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.6/3.9 MB 11.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.1/3.9 MB 11.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.6/3.9 MB 12.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.2/3.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------- ------------ 2.7/3.9 MB 12.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.9 MB 12.2 MB/s eta 0:00:01
#    ---------------------------------------  3.9/3.9 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.9/3.9 MB 11.9 MB/s eta 0:00:00
# Installing collected packages: lxml, pandas-datareader
# Successfully installed lxml-4.9.3 pandas-datareader-0.10.0

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
import pandas_datareader.data as web
from pandas_datareader.famafrench import get_available_datasets

datasets = get_available_datasets()
datasets[1:20]
# Out:
# ['F-F_Research_Data_Factors_weekly',
#  'F-F_Research_Data_Factors_daily',
#  'F-F_Research_Data_5_Factors_2x3',
#  'F-F_Research_Data_5_Factors_2x3_daily',
#  'Portfolios_Formed_on_ME',
#  'Portfolios_Formed_on_ME_Wout_Div',
#  'Portfolios_Formed_on_ME_Daily',
#  'Portfolios_Formed_on_BE-ME',
#  'Portfolios_Formed_on_BE-ME_Wout_Div',
#  'Portfolios_Formed_on_BE-ME_Daily',
#  'Portfolios_Formed_on_OP',
#  'Portfolios_Formed_on_OP_Wout_Div',
#  'Portfolios_Formed_on_OP_Daily',
#  'Portfolios_Formed_on_INV',
#  'Portfolios_Formed_on_INV_Wout_Div',
#  'Portfolios_Formed_on_INV_Daily',
#  '6_Portfolios_2x3',
#  '6_Portfolios_2x3_Wout_Div',
#  '6_Portfolios_2x3_weekly']

# %%
# PBR별 포트폴리오의 수익률

df_pbr = web.DataReader('Portfolios_Formed_on_BE-ME',
                        'famafrench',
                        start='2010-01-01')
df_pbr[0].head()
# Out:
#          <= 0  Lo 30  Med 40  Hi 30  Lo 20  Qnt 2  Qnt 3  Qnt 4  Hi 20  Lo 10  \
# Date
# 2010-01  1.38  -4.19   -2.13  -4.08  -4.14  -3.57  -1.73  -4.36  -1.21  -4.01
# 2010-02  4.61   3.07    3.03   5.86   2.83   2.80   3.78   4.76   6.54   2.66
# 2010-03  9.58   5.31    6.88   7.98   5.42   6.29   6.40   6.64   9.49   4.88
# 2010-04  4.14   0.99    3.11   3.02   0.85   3.10   2.09   1.47   5.54   0.82
# 2010-05 -8.82  -7.31   -8.35  -8.44  -7.15  -7.96  -8.61  -7.91  -9.44  -7.89
#
#          Dec 2  Dec 3  Dec 4  Dec 5  Dec 6  Dec 7  Dec 8  Dec 9  Hi 10
# Date
# 2010-01  -4.27  -4.40  -2.85  -0.40  -3.30  -1.28  -6.71  -1.57  -0.83
# 2010-02   3.01   3.99   1.80   4.26   3.20   4.21   5.20   4.27   8.92
# 2010-03   5.96   4.91   7.46   4.42   8.83   6.80   6.50   8.59  10.39
# 2010-04   0.87   1.54   4.39   1.24   3.09   2.75   0.46   6.01   5.08
# 2010-05  -6.40  -7.94  -7.99  -8.16  -9.13  -8.58  -7.36  -8.79 -10.09

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)

df_pbr_vw = df_pbr[0].loc[:, ['Lo 20', 'Qnt 2', 'Qnt 3', 'Qnt 4', 'Hi 20']]
df_pbr_cum = (1 + df_pbr_vw / 100).cumprod()
df_pbr_cum.plot(figsize=(10, 6),
                colormap=cm.jet,
                legend='reverse',
                title='PBR별 포트폴리오의 누적 수익률')
plt.show()

# %%
import numpy as np

df_pbr_cum = np.log(1+df_pbr_vw/100).cumsum()
df_pbr_cum.plot(figsize=(10, 6),
                colormap=cm.jet,
                legend='reverse',
                title='PBR별 포트폴리오의 누적 수익률')
plt.show()

# %%
import pandas as pd

def factor_stat(df):

    n = len(df)

    ret_ari = (df / 100).mean(axis=0) * 12
    ret_geo = (1 + df / 100).prod()**(12 / n) - 1
    vol = (df / 100).std(axis=0) * np.sqrt(12)
    sharp = ret_ari / vol

    stat = pd.DataFrame(
        [ret_ari, ret_geo, vol, sharp],
        index=['연율화 수익률(산술)', '연율화 수익률(기하)', '연율화 변동성', '샤프지수']).round(4)

    stat.iloc[0:3, ] = stat.iloc[0:3, ] * 100

    return stat

# %%
factor_stat(df_pbr_vw)
# Out:
#                Lo 20    Qnt 2    Qnt 3    Qnt 4    Hi 20
# 연율화 수익률(산술)  15.1000  12.2700  11.4000   9.9100  11.3100
# 연율화 수익률(기하)  14.7300  11.8500  10.6800   8.8100   9.1300
# 연율화 변동성      16.0700  14.3500  15.5700  16.9100  22.3200
# 샤프지수          0.9396   0.8553   0.7322   0.5862   0.5067

# %%
df_per = web.DataReader('Portfolios_Formed_on_E-P',
                        'famafrench',
                        start='2010-01-01')
df_per_vw = df_per[0].loc[:, ['Lo 20', 'Qnt 2', 'Qnt 3', 'Qnt 4', 'Hi 20']]
df_per_cum = np.log(1 + df_per_vw / 100).cumsum()
df_per_cum.plot(figsize=(10, 6),
                colormap=cm.jet,
                legend='reverse',
                title='PER별 포트폴리오의 누적 수익률')
plt.show()

# %%
df_pcr = web.DataReader('Portfolios_Formed_on_CF-P',
                        'famafrench',
                        start='2010-01-01')
df_pcr_vw = df_pcr[0].loc[:, ['Lo 20', 'Qnt 2', 'Qnt 3', 'Qnt 4', 'Hi 20']]
df_pcr_cum = np.log(1 + df_pcr_vw / 100).cumsum()
df_pcr_cum.plot(figsize=(10, 6),
                colormap=cm.jet,
                legend='reverse',
                title='PCR별 포트폴리오의 누적 수익률')
plt.show()

# %%
# !pip install SQLAlchemy
# Out:
# Collecting SQLAlchemy
#   Downloading SQLAlchemy-2.0.23-cp38-cp38-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\venv\jupyter38\lib\site-packages (from SQLAlchemy) (4.5.0)
# Collecting greenlet!=0.4.17 (from SQLAlchemy)
#   Downloading greenlet-3.0.2-cp38-cp38-win_amd64.whl.metadata (3.8 kB)
# Downloading SQLAlchemy-2.0.23-cp38-cp38-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------- ---------------------------- 0.6/2.1 MB 12.0 MB/s eta 0:00:01
#    --------------------- ------------------ 1.1/2.1 MB 12.0 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.1 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 11.9 MB/s eta 0:00:00
# Downloading greenlet-3.0.2-cp38-cp38-win_amd64.whl (287 kB)
#    ---------------------------------------- 0.0/287.3 kB ? eta -:--:--
#    ---------------------------------------- 287.3/287.3 kB 8.9 MB/s eta 0:00:00
# Installing collected packages: greenlet, SQLAlchemy
# Successfully installed SQLAlchemy-2.0.23 greenlet-3.0.2

# %%
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.0-py3-none-any.whl.metadata (4.4 kB)
# Downloading PyMySQL-1.1.0-py3-none-any.whl (44 kB)
#    ---------------------------------------- 0.0/44.8 kB ? eta -:--:--
#    ---------------------------------------- 44.8/44.8 kB ? eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.0

# %%
import pickle
with open('stock_db.pkl', 'rb') as f:
    data = pickle.load(f)

ticker_list = data[0]   # 티커
sector_list = data[1]   # 섹터
price_list = data[2]    # 주가
fs_list = data[3]       # 재무제표
value_list = data[4]    # 밸류지표(TTM)

# %%
value_list
# Out:
#          종목코드         기준일   지표        값
# 0      000020  2023-01-25   DY   0.0195
# 1      000020  2023-01-25  PBR   0.7060
# 2      000020  2023-01-25  PCR   5.7809
# 3      000020  2023-01-25  PER  10.1679
# 4      000020  2023-01-25  PSR   0.7741
# ...       ...         ...  ...      ...
# 28024  441270  2023-05-02  PSR      NaN
# 28025  446070  2023-05-02  PBR      NaN
# 28026  446070  2023-05-02  PCR      NaN
# 28027  446070  2023-05-02  PER      NaN
# 28028  446070  2023-05-02  PSR      NaN
#
# [28029 rows x 4 columns]

# %%
value_list.loc[value_list['값'] <= 0, '값'] = np.nan
value_pivot = value_list.pivot(index='종목코드', columns='지표', values='값')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\MyJob\seyeon\sesac\transformer-for-finance\src\ch4_etf\factor.ipynb Cell 16 line 2
#       <a href='vscode-notebook-cell:/c%3A/MyJob/seyeon/sesac/transformer-for-finance/src/ch4_etf/factor.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> value_list.loc[value_list['값'] <= 0, '값'] = np.nan
# ----> <a href='vscode-notebook-cell:/c%3A/MyJob/seyeon/sesac/transformer-for-finance/src/ch4_etf/factor.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> value_pivot = value_list.pivot(index='종목코드', columns='지표', values='값')
#
# File c:\venv\jupyter38\lib\site-packages\pandas\core\frame.py:8414, in DataFrame.pivot(self, columns, index, values)
#    8409 @Substitution("")
#    8410 @Appender(_shared_docs["pivot"])
#    8411 def pivot(self, *, columns, index=lib.NoDefault, values=lib.NoDefault) -> DataFrame:
#    8412     from pandas.core.reshape.pivot import pivot
# -> 8414     return pivot(self, index=index, columns=columns, values=values)
#
# File c:\venv\jupyter38\lib\site-packages\pandas\core\reshape\pivot.py:557, in pivot(data, columns, index, values)
#     553         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     554 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     555 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     556 # "Hashable"
# --> 557 result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     558 result.index.names = [
#     559     name if name is not lib.NoDefault else None for name in result.index.names
#     560 ]
#     562 return result
#
# File c:\venv\jupyter38\lib\site-packages\pandas\core\series.py:4313, in Series.unstack(self, level, fill_value)
#    4270 """
#    4271 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4272
#    (...)
#    4309 b    2    4
#    4310 """
#    4311 from pandas.core.reshape.reshape import unstack
# -> 4313 return unstack(self, level, fill_value)
#
# File c:\venv\jupyter38\lib\site-packages\pandas\core\reshape\reshape.py:488, in unstack(obj, level, fill_value)
#     486 if is_1d_only_ea_dtype(obj.dtype):
#     487     return _unstack_extension_series(obj, level, fill_value)
# --> 488 unstacker = _Unstacker(
#     489     obj.index, level=level, constructor=obj._constructor_expanddim
#     490 )
#     491 return unstacker.get_result(
#     492     obj._values, value_columns=None, fill_value=fill_value
#     493 )
#
# File c:\venv\jupyter38\lib\site-packages\pandas\core\reshape\reshape.py:136, in _Unstacker.__init__(self, index, level, constructor)
#     128 if num_cells > np.iinfo(np.int32).max:
#     129     warnings.warn(
#     130         f"The following operation may generate {num_cells} cells "
#     131         f"in the resulting pandas object.",
#     132         PerformanceWarning,
#     133         stacklevel=find_stack_level(),
#     134     )
# --> 136 self._make_selectors()
#
# File c:\venv\jupyter38\lib\site-packages\pandas\core\reshape\reshape.py:188, in _Unstacker._make_selectors(self)
#     185 mask.put(selector, True)
#     187 if mask.sum() < len(self.index):
# --> 188     raise ValueError("Index contains duplicate entries, cannot reshape")
#     190 self.group_index = comp_index
#     191 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape
